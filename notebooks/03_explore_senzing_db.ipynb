# %% [markdown]
# # Exploring the Senzing Database
#
# After loading data and running entity resolution, Senzing stores everything in PostgreSQL.
# This notebook lets you look under the hood at what Senzing created.

# %%
import os
import json
import psycopg2
import pandas as pd
import re
from collections import Counter

conn = psycopg2.connect(
    host=os.getenv('POSTGRES_HOST', 'postgres'),
    port=os.getenv('POSTGRES_PORT', '5432'),
    user=os.getenv('POSTGRES_USER', 'postgres'),
    password=os.getenv('POSTGRES_PASSWORD', 'workshop'),
    database=os.getenv('POSTGRES_DB', 'erkg')
)
print('Connected to PostgreSQL')
# Out:
# Connected to PostgreSQL

# %% [markdown]
# ## Table Overview
#
# Senzing creates 16 tables. Here's what each one holds and how many rows are in it.

# %%
table_descriptions = {
    'dsrc_record':    'Raw source records (the original JSON you loaded)',
    'lib_feat':       'Feature library (extracted names, addresses, DOBs, IDs, etc.)',
    'obs_ent':        'Observed entities (one per source record)',
    'res_ent':        'Resolved entities (after entity resolution)',
    'res_ent_okey':   'Maps source records to resolved entities',
    'res_feat_ekey':  'Maps features to entities',
    'res_feat_stat':  'Feature statistics used for scoring',
    'res_rel_ekey':   'Relationship-to-entity key mapping',
    'res_relate':     'Relationships between resolved entities',
    'sys_cfg':        'Engine configurations',
    'sys_codes_used': 'Feature types and codes in use',
    'sys_eval_queue': 'Records queued for re-evaluation',
    'sys_hw_check':   'Hardware check info',
    'sys_sequence':   'ID sequence counters',
    'sys_status':     'System status',
    'sys_vars':       'System variables'
}

cursor = conn.cursor()

rows = []
for table, desc in table_descriptions.items():
    try:
        cursor.execute(f'SELECT COUNT(*) FROM {table}')
        count = cursor.fetchone()[0]
    except Exception:
        conn.rollback()
        count = 'N/A'
    rows.append({'Table': table, 'Rows': count, 'Description': desc})

df_tables = pd.DataFrame(rows)
df_tables
# Out:
#              Table  Rows                                        Description
# 0      dsrc_record   282  Raw source records (the original JSON you loaded)
# 1         lib_feat  8184  Feature library (extracted names, addresses, D...
# 2          obs_ent   282          Observed entities (one per source record)
# 3          res_ent   196        Resolved entities (after entity resolution)
# 4     res_ent_okey   282           Maps source records to resolved entities
# 5    res_feat_ekey  9706                          Maps features to entities
# 6    res_feat_stat  8183                Feature statistics used for scoring
# 7     res_rel_ekey   984                 Relationship-to-entity key mapping
# 8       res_relate   492            Relationships between resolved entities
# 9          sys_cfg     3                              Engine configurations
# 10  sys_codes_used    96                     Feature types and codes in use
# 11  sys_eval_queue    91                   Records queued for re-evaluation
# 12    sys_hw_check     0                                Hardware check info
# 13    sys_sequence     5                               ID sequence counters
# 14      sys_status     0                                      System status
# 15        sys_vars     2                                   System variables

# %% [markdown]
# ## Source Records (`dsrc_record`)
#
# Every record you loaded is stored here with its original JSON. The `dsrc_id` identifies the data source,
# and `ent_src_key` is a hash Senzing uses internally.

# %%
df_records = pd.read_sql("""
    SELECT dsrc_id, record_id, ent_src_key, json_data
    FROM dsrc_record
    ORDER BY dsrc_id, record_id
""", conn)

print(f'Total source records: {len(df_records)}')
print(f'\nRecords per data source ID:')
print(df_records.groupby('dsrc_id').size().to_string())
print(f'\nSample records:')
df_records[['dsrc_id', 'record_id', 'ent_src_key']].head(10)
# Out:
# Total source records: 282
#
# Records per data source ID:
# dsrc_id
# 1004    258
# 1005     24
#
# Sample records:
# /tmp/ipykernel_22497/705132723.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_records = pd.read_sql("""
#    dsrc_id             record_id                               ent_src_key
# 0     1004  10094521532396971848  CCD2814C008317064FB5CEF8411F6F7E513C5D21
# 1     1004  10165632722354515453  2664895F8D5B451FAB6EDA63EE1DAD2BED3706FC
# 2     1004  10264459789712927869  276B0D9C39DFE6E4B84EA529E29830A0B1658900
# 3     1004  10369029484097831758  D2E6B15C99FD258E5CE99D2A08704A24015F844F
# 4     1004  10390699576067371333  06D5595D5B8C3D15D209772D1D547C79820089CA
# 5     1004  10442160967680700142  636829580A90CB0E8678B1DF4A870D1778E09B87
# 6     1004  10503886662016933171  2657DC249E473AA2368791A2851B41EDE4190BEC
# 7     1004  10534369556549149800  EEBEF8810A846BDBC4CD01D11DC9EA3FF24F151A
# 8     1004  10540071752248991376  B10F75DB902C76C14EF2618F59EECBC1CCFD2A7D
# 9     1004  10572239874396124657  CB0CB39124A26B0CD2203BA29E2000780D5156A8

# %% [markdown]
# ## Let's check out one record...

# %%
sample = df_records.iloc[0]
print(f'Data Source ID: {sample["dsrc_id"]}')
print(f'Record ID: {sample["record_id"]}')
print(f'\nStored JSON:')
print(json.dumps(json.loads(sample['json_data']), indent=2)[:2000])
# Out:
# Data Source ID: 1004
# Record ID: 10094521532396971848
#
# Stored JSON:
# {
#   "DATA_SOURCE": "OPEN-OWNERSHIP",
#   "RECORD_ID": "10094521532396971848",
#   "FEATURES": [
#     {
#       "RECORD_TYPE": "ORGANIZATION"
#     },
#     {
#       "NAME_ORG": "GOLD WYNN UK HOLDINGS LIMITED"
#     },
#     {
#       "REGISTRATION_DATE": "2020-03-18"
#     },
#     {
#       "REGISTRATION_COUNTRY": "GB"
#     },
#     {
#       "ADDR_TYPE": "BUSINESS",
#       "ADDR_FULL": "C/O Fladgate Llp, 16 Great Queen Street, London, WC2B 5DG"
#     },
#     {
#       "NATIONAL_ID_NUMBER": "12524623",
#       "NATIONAL_ID_TYPE": "GB-COH",
#       "NATIONAL_ID_COUNTRY": "GBR"
#     },
#     {
#       "REL_ANCHOR_DOMAIN": "OOR",
#       "REL_ANCHOR_KEY": "10094521532396971848"
#     },
#     {
#       "REL_POINTER_DOMAIN": "OOR",
#       "REL_POINTER_KEY": "7584591804488095167",
#       "REL_POINTER_ROLE": "shareholding 75% 100%"
#     },
#     {
#       "REL_POINTER_DOMAIN": "OOR",
#       "REL_POINTER_KEY": "7584591804488095167",
#       "REL_POINTER_ROLE": "voting_rights 75% 100%"
#     },
#     {
#       "REL_POINTER_DOMAIN": "OOR",
#       "REL_POINTER_KEY": "7584591804488095167",
#       "REL_POINTER_ROLE": "appointment_of_board"
#     }
#   ],
#   "statementDate": "2023-06-18",
#   "link_OpenCorporates": "https://opencorporates.com/companies/gb/12524623",
#   "link_OpenOwnership_Register": "https://register.openownership.org/entities/18432059995972240708"
# }

# %% [markdown]
# ## Resolved Entities (`res_ent`)
#
# This is the output of entity resolution — each row is a unique entity that Senzing identified.
# 282 source records were collapsed into 196 entities (30.5% reduction).  Note tht `res_ent_id` is the `ENTITY_ID` you see whe you call `get_entity_by_record_id()` and is Senzing's unique identifier for a resolved entity.  `locking_id` is a lock partition number that the entity falls into (not used for analysis, but as  an internal concurrency control).

# %%
df_entities = pd.read_sql("""
    SELECT res_ent_id, locking_id
    FROM res_ent
    ORDER BY res_ent_id
""", conn)

print(f'Total resolved entities: {len(df_entities)}')
df_entities.head(10)
# Out:
# Total resolved entities: 196
# /tmp/ipykernel_22497/3542555449.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_entities = pd.read_sql("""
#    res_ent_id  locking_id
# 0      100001           3
# 1      100002           1
# 2      100003           1
# 3      100004           1
# 4      100005           1
# 5      100006           2
# 6      100007           1
# 7      100008           1
# 8      100009           1
# 9      100010           2

# %% [markdown]
# ## Record-to-Entity Mapping (`res_ent_okey`)
#
# This table shows which source records map to which resolved entities.
# When multiple records map to the same `res_ent_id`, that's entity resolution in action.
#
# Match Key tells you what features matched between two records. It's a string like `+NAME+DOB+PHONE` where `+` means the feature matched and `-` means it didn't. So `+NAME+DOB+ADDRESS-PHONE` means name, DOB, and address all matched, but the phone numbers were different.
#
# ER Rule (entity resolution rule) tells you which rule Senzing applied to make its decision. Each rule defines a combination of features that is sufficient to consider two records the same entity.  These rules are numbers, which specify internal rule IDs that define specific feature combinations.

# %%
df_mapping = pd.read_sql("""
    SELECT *
    FROM res_ent_okey
    ORDER BY res_ent_id
""", conn)

print(f'Total mappings: {len(df_mapping)}')
print(f'\nColumns: {list(df_mapping.columns)}')
df_mapping.head(10)
# Out:
# Total mappings: 282
#
# Columns: ['obs_ent_id', 'res_ent_id', 'errule_id', 'match_key']
# /tmp/ipykernel_22497/92529021.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mapping = pd.read_sql("""
#    obs_ent_id  res_ent_id  errule_id  \
# 0      100001      100001          0
# 1      100145      100001        162
# 2      100235      100001        180
# 3      100002      100002          0
# 4      100003      100003          0
# 5      100004      100004          0
# 6      100005      100005          0
# 7      100006      100006          0
# 8      100017      100006        108
# 9      100007      100007          0
#
#                                            match_key
# 0                                               None
# 1                          +NAME+ADDRESS+NATIONALITY
# 2                              +NAME+DOB+NATIONALITY
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8  +NAME+ADDRESS+TAX_ID+NATIONAL_ID+REGISTRATION_...
# 9                                               None

# %% [markdown]
# ## Merged entities
#
# Let's look at the entities that merged multiple records (i.e. the interesting ones).

# %%
entity_counts = df_mapping.groupby('res_ent_id').size().reset_index(name='record_count')
merged = entity_counts[entity_counts['record_count'] > 1].sort_values('record_count', ascending=False)

print(f'Entities with multiple records: {len(merged)} out of {len(entity_counts)}')
print(f'\nTop merged entities:')
merged.head(20)
# Out:
# Entities with multiple records: 67 out of 196
#
# Top merged entities:
#      res_ent_id  record_count
# 88       100102             4
# 89       100104             4
# 56       100061             4
# 70       100078             3
# 92       100108             3
# 101      100120             3
# 105      100124             3
# 43       100048             3
# 42       100047             3
# 40       100045             3
# 110      100131             3
# 36       100041             3
# 154      100200             3
# 150      100193             3
# 23       100028             3
# 0        100001             3
# 86       100100             2
# 183      100255             2
# 179      100249             2
# 90       100105             2

# %% [markdown]
# ## Feature Library (`lib_feat`)
#
# Senzing extracts features (names, addresses, phone numbers, IDs, etc.) from every record
# and stores them in a normalized library. These features are what get compared during matching.  The following columns are included:
#
# - `lib_feat_id: Auto-incrementing unique ID for each feature in the library
# - `ftype_id`: Feature type ID — identifies what kind of feature this is (name, address, DOB, phone, identifier, etc.). Maps to an internal lookup table in the Senzing config.
# - `version`: Schema version for how this feature was extracted/encoded. Different feature types can have different versions.
# - `feat_hash`: SHA-1 hash of the feature value. Senzing uses this for fast deduplication — if two records produce the same hash, they share the same feature.
# - `feat_desc`: The human-readable feature value. This is what you'd recognize: "Robert Smith", "123 Main Street, Las Vegas NV 89132", "702-919-1300", etc.
# - `felem_values`: The tokenized/decomposed version of the feature. Senzing breaks features into elements for matching — e.g., a name becomes "2:Robert Smith|4:Smith|5:Robert|10:ANGLO|12:PERSON" where each number is an element type (full name, surname, given name, name origin, record type).
# - `anonymized`: N or Y — whether this feature has been anonymized.

# %%
df_features = pd.read_sql("""
    SELECT *
    FROM lib_feat
    ORDER BY lib_feat_id
    LIMIT 30
""", conn)

df_features.head(10)
# Out:
# /tmp/ipykernel_22497/3896006920.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_features = pd.read_sql("""
#    lib_feat_id  ftype_id  version                                 feat_hash  \
# 0       100001         1        2  72702780939ED12602261A95064134135DD5EDFC
# 1       100002         2        2  BC5A459E1CE57A4354B0550E23797E296B439443
# 2       100003         5        4  F17E683A6A083025F03B8AFB88164DB4D867C54C
# 3       100004        18        1  22F316394D0DFB3A74D037CD5BB18132AB2DA1E1
# 4       100005        19        1  14459E8DA577F17BC816E1ADDC48B5B5AAEF9095
# 5       100006        19        1  1BAE6EC9392BEC0B75124D3C34848BC4E226E8C5
# 6       100007        19        1  EC6E93158D778F395392D5BD357CAA9B702228DB
# 7       100008        20        1  CF0DE6BFB15D25222E05402C02E392991CACB083
# 8       100009        52        2  BB3ABBF00127585CA036A61B1136046846425DE6
# 9       100010        55        2  926C04B1CFDE891A24A4A1A7F944E7BC985827E8
#
#                                            feat_desc  \
# 0                                    Abassin BADSHAH
# 1                                         1985-05-12
# 2  31 Quernmore Close, Bromley, Kent, United King...
# 3                                           APSN|PTX
# 4                                 31|KRNMR KLS||PRML
# 5                                  31|KRNMR KLS||KNT
# 6                               31|KRNMR KLS||BR14EL
# 7                  OTHER_ID=NK25VYVFZT8VDJGGAXMRTWTJ
# 8           NK-25vyVFzt8vdJGgAXMRTwTJ OPEN-SANCTIONS
# 9                                                 gb
#
#                                         felem_values anonymized
# 0  2:Abassin BADSHAH|10:SOUTHWESTASIAN|12:PERSON|...          N
# 1  43:1985-05-12|62:1985|63:5|64:12|71:81205|112:...          N
# 2  28:UNITED KINGDOM|29:31|72:KRNMR KLS|73L:PRML,...          N
# 3                                      36:APSN\|PTX|          N
# 4                          36:31\|KRNMR KLS\|\|PRML|          N
# 5                           36:31\|KRNMR KLS\|\|KNT|          N
# 6                        36:31\|KRNMR KLS\|\|BR14EL|          N
# 7              36:OTHER_ID=NK25VYVFZT8VDJGGAXMRTWTJ|          N
# 8  37:NK-25vyVFzt8vdJGgAXMRTwTJ|38:OPEN-SANCTIONS...          N
# 9                                     28:gb|117:GBR|          N

# %% [markdown]
# ## Counting features by type

# %%
config_df = pd.read_sql("SELECT config_data FROM sys_cfg ORDER BY sys_create_dt DESC LIMIT 1", conn)
config = json.loads(config_df.iloc[0]['config_data'])
ftype_lookup = {ft['FTYPE_ID']: ft['FTYPE_CODE'] for ft in config['G2_CONFIG']['CFG_FTYPE']}

df_feat_counts = pd.read_sql("""
    SELECT ftype_id, COUNT(*) as feature_count
    FROM lib_feat
    GROUP BY ftype_id
    ORDER BY feature_count DESC
""", conn)

df_feat_counts['feature_type'] = df_feat_counts['ftype_id'].map(ftype_lookup)
df_feat_counts
# Out:
# /tmp/ipykernel_22497/175974684.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   config_df = pd.read_sql("SELECT config_data FROM sys_cfg ORDER BY sys_create_dt DESC LIMIT 1", conn)
# /tmp/ipykernel_22497/175974684.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_feat_counts = pd.read_sql("""
#     ftype_id  feature_count          feature_type
# 0         94           2573          NAMEDATE_KEY
# 1         96           1723        NAMEREGION_KEY
# 2         92           1679          NAMEADDR_KEY
# 3         18            467              NAME_KEY
# 4          1            388                  NAME
# 5         89            275            REL_ANCHOR
# 6         20            190                ID_KEY
# 7         90            187           REL_POINTER
# 8         19            149              ADDR_KEY
# 9         12            148           NATIONAL_ID
# 10         5            141               ADDRESS
# 11        75            113     REGISTRATION_DATE
# 12         2             47                   DOB
# 13        74             28        PLACE_OF_BIRTH
# 14        52             26              OTHER_ID
# 15        10             10              PASSPORT
# 16        76              9  REGISTRATION_COUNTRY
# 17        11              9                TAX_ID
# 18        55              7           NATIONALITY
# 19        53              5            TRUSTED_ID
# 20        54              3           CITIZENSHIP
# 21        72              2           RECORD_TYPE
# 22        15              2               WEBSITE
# 23         4              2                GENDER
# 24        58              1      AMBIGUOUS_ENTITY

# %% [markdown]
# ## Relationships (`res_relate`)
#
# This is the edges of your knowledge graph. Each row is a relationship between two resolved entities.
# The `match_key` shows what features matched (`+`) or didn't match (`-`) between them.

# %%
df_rels = pd.read_sql("""
    SELECT min_res_ent_id, max_res_ent_id, 
           is_disclosed, is_ambiguous, 
           match_key, match_levels
    FROM res_relate
    ORDER BY min_res_ent_id
""", conn)

print(f'Total relationships: {len(df_rels)}')
print(f'Disclosed relationships: {df_rels["is_disclosed"].sum()}')
print(f'Ambiguous relationships: {df_rels["is_ambiguous"].sum()}')
print(f'\nSample relationships:')
df_rels.head(15)
# Out:
# Total relationships: 492
# Disclosed relationships: 233
# Ambiguous relationships: 2
#
# Sample relationships:
# /tmp/ipykernel_546/2841567355.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_rels = pd.read_sql("""
#     min_res_ent_id  max_res_ent_id  is_disclosed  is_ambiguous  \
# 0           100001          100009             1             0
# 1           100001          100099             1             0
# 2           100001          100002             1             0
# 3           100001          100155             1             0
# 4           100001          100156             0             0
# 5           100002          100009             0             0
# 6           100002          100099             0             0
# 7           100005          100008             0             0
# 8           100005          100012             0             0
# 9           100005          100013             1             0
# 10          100005          100007             0             0
# 11          100006          100018             1             0
# 12          100006          100012             1             0
# 13          100006          100016             1             0
# 14          100006          100015             0             0
#
#                                             match_key match_levels
# 0   +ADDRESS+REL_POINTER(DOMAIN:OPEN\-SANCTIONS|MI...         3,11
# 1   +ADDRESS+REL_POINTER(DOMAIN:OOR|MIN:|MAX:APPOI...         3,11
# 2   +ADDRESS+REL_POINTER(DOMAIN:OPEN\-SANCTIONS|MI...         3,11
# 3   +ADDRESS+REL_POINTER(DOMAIN:OOR|MIN:|MAX:SHARE...         3,11
# 4                            +ADDRESS+NATIONALITY-DOB            3
# 5                       +ADDRESS+REGISTRATION_COUNTRY            3
# 6                       +ADDRESS+REGISTRATION_COUNTRY            3
# 7   +ADDRESS+CITIZENSHIP+NATIONALITY+PLACE_OF_BIRT...            3
# 8   +ADDRESS+CITIZENSHIP+NATIONALITY-DOB-GENDER-PA...            3
# 9   +REL_POINTER(DOMAIN:OPEN\-SANCTIONS|MIN:FAMILY...           11
# 10  +ADDRESS+CITIZENSHIP+NATIONALITY-DOB-PASSPORT-...            3
# 11  +ADDRESS+OTHER_ID+REGISTRATION_COUNTRY+REL_POI...         3,11
# 12  +REL_POINTER(DOMAIN:OPEN\-SANCTIONS|MIN:|MAX:У...           11
# 13  +REL_POINTER(DOMAIN:OPEN\-SANCTIONS|MIN:CONTRO...           11
# 14  +ADDRESS+OTHER_ID+REGISTRATION_COUNTRY-TAX_ID-...            3

# %% [markdown]
# ## Analyzing match keys
#
# The following code will show you which features where matched on (`+`) in the ER and how often, along with which features were NOT matched on (`-`).

# %%
positive_features = Counter()
negative_features = Counter()

for mk in df_rels['match_key']:
    if mk:
        for feat in re.findall(r'\+([A-Z_]+)', mk):
            positive_features[feat] += 1
        for feat in re.findall(r'-([A-Z_]+)', mk):
            negative_features[feat] += 1

print('Features that MATCHED (+) across related entities:')
for feat, count in positive_features.most_common(15):
    print(f'  +{feat}: {count} relationships')

print(f'\nFeatures that DID NOT match (-) across related entities:')
for feat, count in negative_features.most_common(15):
    print(f'  -{feat}: {count} relationships')
# Out:
# Features that MATCHED (+) across related entities:
#   +ADDRESS: 287 relationships
#   +REL_POINTER: 233 relationships
#   +REGISTRATION_COUNTRY: 174 relationships
#   +NATIONALITY: 42 relationships
#   +NAME: 24 relationships
#   +REGISTRATION_DATE: 12 relationships
#   +CITIZENSHIP: 7 relationships
#   +LIKELY_NAME: 7 relationships
#   +DOB: 6 relationships
#   +OTHER_ID: 3 relationships
#   +PLACE_OF_BIRTH: 2 relationships
#
# Features that DID NOT match (-) across related entities:
#   -NATIONAL_ID: 161 relationships
#   -REGISTRATION_DATE: 151 relationships
#   -RECORD_TYPE: 83 relationships
#   -SANCTIONS: 14 relationships
#   -DOB: 11 relationships
#   -TAX_ID: 6 relationships
#   -GENDER: 3 relationships
#   -PASSPORT: 3 relationships
#   -ADDRESS: 1 relationships

# %% [markdown]
# ## Engine Configuration (`sys_cfg`)
#
# Senzing stores its configuration as JSON in this table. This includes all data source definitions,
# feature types, matching rules, and scoring thresholds.

# %%
df_cfg = pd.read_sql("""
    SELECT config_data_id, config_comments, sys_create_dt
    FROM sys_cfg
    ORDER BY sys_create_dt
""", conn)

print('Configuration history:')
df_cfg
# Out:
# Configuration history:
# /tmp/ipykernel_546/4247072541.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_cfg = pd.read_sql("""
#    config_data_id                                    config_comments  \
# 0       948463713  Created by init-database at 2026-03-16T21:33:2...
# 1       367646059      Workshop configuration with test data sources
# 2      3123367707  Added data sources: OPEN-OWNERSHIP, OPEN-SANCT...
#
#             sys_create_dt
# 0 2026-03-16 21:33:29.219
# 1 2026-03-16 21:33:53.840
# 2 2026-03-16 21:35:23.107

# %% [markdown]
# ## Confirm what data sources are presently in our database

# %%
cursor = conn.cursor()
cursor.execute("""
    SELECT config_data FROM sys_cfg 
    ORDER BY sys_create_dt DESC LIMIT 1
""")

config = json.loads(cursor.fetchone()[0])

print('Registered data sources:')
for ds in config.get('G2_CONFIG', {}).get('CFG_DSRC', []):
    print(f"  ID {ds['DSRC_ID']}: {ds['DSRC_CODE']}")
# Out:
# Registered data sources:
#   ID 1: TEST
#   ID 2: SEARCH
#   ID 1001: CUSTOMERS
#   ID 1002: REFERENCE
#   ID 1003: WATCHLIST
#   ID 1004: OPEN-OWNERSHIP
#   ID 1005: OPEN-SANCTIONS

# %% [markdown]
# ## Summary Statistics

# %%
cursor = conn.cursor()

cursor.execute('SELECT COUNT(*) FROM dsrc_record')
total_records = cursor.fetchone()[0]

cursor.execute('SELECT COUNT(*) FROM res_ent')
total_entities = cursor.fetchone()[0]

cursor.execute('SELECT COUNT(*) FROM res_relate')
total_rels = cursor.fetchone()[0]

cursor.execute('SELECT COUNT(*) FROM lib_feat')
total_features = cursor.fetchone()[0]

print('Senzing Database Summary')
print('=' * 50)
print(f'Source records loaded:     {total_records:>6,}')
print(f'Resolved entities:        {total_entities:>6,}')
print(f'Records merged:           {total_records - total_entities:>6,}')
print(f'Reduction:                {(total_records - total_entities) / total_records * 100:>5.1f}%')
print(f'Entity relationships:     {total_rels:>6,}')
print(f'Features extracted:       {total_features:>6,}')
print(f'Avg features per record:  {total_features / total_records:>6.1f}')
print('=' * 50)
# Out:
# Senzing Database Summary
# ==================================================
# Source records loaded:        282
# Resolved entities:           196
# Records merged:               86
# Reduction:                 30.5%
# Entity relationships:        492
# Features extracted:        8,184
# Avg features per record:    29.0
# ==================================================

# %%
conn.close()
print('Connection closed')
# Out:
# Connection closed
